# %%
import pandas as pd
import requests
import time
from datetime import datetime
from pyspark.sql.functions import *

# %%
df_weather_spark = spark.sql(f"""SELECT * FROM delta. `/dbfs/Silver/ExtraçãoTempo` """)

# %%
df_weather_spark.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_temperature_spark = df_weather_spark.drop('evapotranspiration','precipitation','humidity')

# %%
df_temperature_spark = df_temperature_spark.orderBy('date','time_str')

# %%
df_temperature_spark.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_temperature_spark.repartition(20)\
              .write.format("delta")\
              .mode("overwrite")\
              .option("overwriteSchema", "true")\
              .save("/dbfs/Silver/Temperature")
